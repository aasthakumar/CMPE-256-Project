# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.model_selection import train_test_split # function for splitting data to train and test sets

import nltk
from nltk.corpus import stopwords
from nltk.classify import SklearnClassifier

from wordcloud import WordCloud,STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output

# %%
data = pd.read_csv('Downloads/deceptive-opinion.csv')
# Keeping only the neccessary columns
data = data[['text','polarity','deceptive']]
data['text'] = data['text'].map(lambda text: text if type(text)!=str else text.lower())

# %%
# Splitting the dataset into train and test set
train, test = train_test_split(data,test_size = 0.2)
# Removing neutral sentiments
train = train[train.polarity != "Neutral"]

# %%
train_pos = train[ train['polarity'] == 'positive']
train_pos = train_pos['text']
train_neg = train[ train['polarity'] == 'negative']
train_neg = train_neg['text']

def wordcloud_draw(data, color = 'black'):
    words = ' '.join(data)
    cleaned_word = " ".join([word for word in words.split()
                            if 'http' not in word
                                and not word.startswith('@')
                                and not word.startswith('#')
                                and word != 'RT'
                            ])
    wordcloud = WordCloud(stopwords=STOPWORDS,
                      background_color=color,
                      width=2500,
                      height=2000
                     ).generate(cleaned_word)
    plt.figure(1,figsize=(13, 13))
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.show()
    
print("Positive words")
wordcloud_draw(train_pos,'white')
print("Negative words")
wordcloud_draw(train_neg)
# Out:
# Positive words
# Negative words

# %%
tweets = []
stopwords_set = set(stopwords.words("english"))

for index, row in train.iterrows():
    words_filtered = [e.lower() for e in row.text.split() if len(e) >= 3]
    words_cleaned = [word for word in words_filtered
        if 'http' not in word
        and not word.startswith('@')
        and not word.startswith('#')
        and word != 'RT']
    words_without_stopwords = [word for word in words_cleaned if not word in stopwords_set]
    tweets.append((words_cleaned,row.polarity))

test_pos = test[ test['polarity'] == 'positive']
test_pos = test_pos['text']
test_neg = test[ test['polarity'] == 'negative']
test_neg = test_neg['text']

# %%
# Extracting word features
def get_words_in_tweets(tweets):
    all = []
    for (words, polarity) in tweets:
        all.extend(words)
    return all

def get_word_features(wordlist):
    wordlist = nltk.FreqDist(wordlist)
    features = wordlist.keys()
    return features
w_features = get_word_features(get_words_in_tweets(tweets))

def extract_features(document):
    document_words = set(document)
    features = {}
    for word in w_features:
        features['containts(%s)' % word] = (word in document_words)
    return features

# %%
wordcloud_draw(w_features)

# %%
# Training the Naive Bayes classifier
training_set = nltk.classify.apply_features(extract_features,tweets)
classifier = nltk.NaiveBayesClassifier.train(training_set)

# %%
neg_cnt = 0
pos_cnt = 0
for obj in test_neg: 
    res =  classifier.classify(extract_features(obj.split()))
    if(res == 'negative'): 
        neg_cnt = neg_cnt + 1
for obj in test_pos: 
    res =  classifier.classify(extract_features(obj.split()))
    if(res == 'positive'): 
        pos_cnt = pos_cnt + 1
        
print('[Negative]: %s/%s '  % (len(test_neg),neg_cnt))        
print('[Positive]: %s/%s '  % (len(test_pos),pos_cnt))
# Out:
# [Negative]: 145/119
# [Positive]: 175/169

# %%
test_neg
# Out:
# 1460    our stay at the sofitel was definitely below o...
# 1014    i'd been searching for a cool, non-chain hotel...
# 1560    i recently had a horrible stay at the intercon...
# 1019    i've used priceline for every trip i've made b...
# 1483    the hotel is located in an hard to fins locati...
# 826     my family of four went to a convention and sta...
# 1488    if you are looking for a true luxury experienc...
# 1524    i've never written a review before, but i just...
# 1266    my husband and i recently stayed at the fairmo...
# 1308    i was in business in chicago, so i decided to ...
# 857     do you imagine getting there for the first tim...
# 1381    the hard rock should stick to restaurants. aft...
# 1403    hi, i had very bad experience with this hotel,...
# 1309    i stayed at the swissotel chicago while i was ...
# 1367    i had high hopes for the ambassador east hotel...
# 1361    my daughter's broken heart my daughter loves a...
# 815     i booked this hotel with great expectations. i...
# 1124    as a frequent traveler to chicago, i generally...
# 875     they rave about their beds but the beds were a...
# 862     the omni was chosen for it's location whichwor...
# 1548    my wife and i were very much looking forward t...
# 1077    the location is ideal. they have very high cei...
# 873     staying here currently. had aspired to sleep. ...
# 1221    on a recent stay at the fairmont chicago mille...
# 1049    after checking out of the sofitel chicago wate...
# 1207    the omni chicago hotel was in one word, dreadf...
# 968     i had requested a quiet room several weeks in ...
# 1482    the hilton chicago, located on prime real esta...
# 1205    i was really looking forward to a nice relaxin...
# 1337    i stayed at the sheraton chicago hotel for a b...
#                               ...
# 1117    i disliked the sofitel so much we changed our ...
# 1230    the omni chicago hotel is not pretty as they a...
# 1467    traveled to this hotel on a family vacation. w...
# 1457    we booked a room at the hilton chicago for two...
# 1486    i had high hopes for the hilton chicago, but i...
# 855     we love the location and proximity to everythi...
# 890     we planned to stay for 5 nights on a family tr...
# 1353    i stayed in the homewood suites in downtown ch...
# 1326    i had really high hopes for this hotel. the lo...
# 1259    recently staying at the omni chicago hotel, wa...
# 948     overall i had a very bad experience when hosti...
# 1497    we stayed at this hotel for our last vacation ...
# 1022    i can see how this place must have been gorgeo...
# 1314    the sheraton chicago is not the place to be if...
# 1165    i usually stay at the hotel monaco but stayed ...
# 834     for a supposed 4-star hotel, i was not very im...
# 1218    i have recently stayed at the fairmont chicago...
# 1068    i valeted my lexus and it was returned with a ...
# 1493    recently stayed at the james chicago and will ...
# 886     three nights there on business. hadn't realize...
# 1530    although the intercontinental chicago hotel is...
# 1158    i stayed in this hotel for 5 days in november ...
# 962     i had purchased this deal of off groupon. lets...
# 1517    my husband and i recently stayed stayed at the...
# 1312    i don't know how this hotel ever got such high...
# 1251    my stay at the fairmont chicago millennium par...
# 1500    i stayed this hotel for 2 nights. i had high h...
# 1125    this hotel is rather stupid to be frank. it's ...
# 1528    i recently stayed at the amalfi hotel in chica...
# 823     the room was very spacious with very nice, col...
# Name: text, Length: 145, dtype: object

# %%
test_pos
# Out:
# 363    i had a great time here! it is centerally loca...
# 580    upon arrival at the ambassador east hotel in c...
# 237    we visited for my 40th birthday. we had never ...
# 421    the windy city fairmont hotel is one of chicag...
# 43     my husband and i decided to take a trip to chi...
# 422    the atmosphere at this hotel is truly remarkab...
# 458    i recently stayed at the hyatt regency in down...
# 592    how should i start? well, after staying at the...
# 74     from the moment i stepped up to the front entr...
# 588    the rates at the talbott hotel were cheaper th...
# 447    the hyatt regency chicago hotel was a delight ...
# 693    this hotel is great! i love its interior desig...
# 502    what a gorgeous hotel! from the moment we step...
# 600    my husband and i decided to plan a romantic ge...
# 747    i stayed here with my family when we were in c...
# 479    my husband and i recently visited the fairmont...
# 452    when my new fiance told me about his business ...
# 219    my wife and i stayed at the ambassador east ho...
# 706    let me just preface this by saying that i abso...
# 111    we absolutely loved the knickerbocker. now, if...
# 178    after reading the reviews & getting an excelle...
# 284    i stayed at this hotel over the weekend of the...
# 213    stayed 5 nights at this great hotel. updated r...
# 338    the only minus for this hotel is they do not p...
# 104    stayed here for one night in june, but have st...
# 639    my husband and i came to the ambassador east h...
# 271    we just arrived from a 3 nights stay at the so...
# 161    i was completely blown away by this hotel. it ...
# 546    this hotel was worth every cent. you have not ...
# 84     the location of this hotel was excellent as it...
#                              ...
# 135    my boyfriend and i were amazed by the breathta...
# 66     we recently completed our second stay at the f...
# 55     we stayed at the omni between christmas and ne...
# 691    recently my husband and i stayed at the james ...
# 88     hi,stayed here for three nights recently,from ...
# 322    my wife and i decided to spend three days in c...
# 380    i stayed at the hotel one night. the hotel is ...
# 339    i stayed at the allegro for several days in au...
# 7      just got back from 2 days up in chicago shoppi...
# 799    the amalfi hotel has become my absolute favori...
# 20     i stayed at the fairmont for a few nights and ...
# 334    we arrived for a weekend stay and really enjoy...
# 199    excellent location, feels like a boutique hote...
# 466    i recently made a business trip to chicago, in...
# 216    stayed here for 4 nights in apri. from check i...
# 169    we just returned from 4 nights at the ambassad...
# 420    overall, the hotel is beautiful. the service w...
# 439    my husband and i went to chicago for three nig...
# 667    beautiful hotel in chicago. i visited this hot...
# 641    i was very satisfied after staying at the sofi...
# 325    i stayed at the allegro in july for 4 nights f...
# 733    i went here with the family, including our dog...
# 277    great beds, clean rooms, amazing bathroom, nif...
# 625    excellent staff and customer service, very cle...
# 744    wow! i have been to many hotels as a business ...
# 302    beautifully appointed, professionally staffed,...
# 415    my husband and i stayed at the hyatt regency w...
# 562    the atmosphere at the talbott hotel is very we...
# 103    the sheraton is a fantastic hotel. my wife and...
# 468    my husband and i stayed at the omni chicago ho...
# Name: text, Length: 175, dtype: object
